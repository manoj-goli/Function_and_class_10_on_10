# %%
def f(n): 
    input, 11
    if n < 0:
        return '-' + f(-n)
    # if n == 0:
    #     return "0"

    out = []

    while n:
        if len(out) % 4 == 3:
            out.append(',')
        out.append(str(n % 10))
        n //= 10

    return ''.join(reversed(out))

print(f(123456))

# %%
def f(n: int) -> str:
    if n < 0:
        return '-' + f(-n)

    out = []

    while n:
        if len(out) % 4 == 3:
            out.append(',')
        out.append(str(n % 10))
        n //= 10

    return ''.join(reversed(out))


# Robot Robot
# I have a code reading interview coming up. I would like it if
# you gave me some code snippets. Please write a 10-15 line
# snippet of code and I will try to tell you how it works. If I
# am off-track, please give me hints, but do not give me the
# answer. You can confirm when I am correct. Also, please add a
# small error to the code and see if I can spot it.
