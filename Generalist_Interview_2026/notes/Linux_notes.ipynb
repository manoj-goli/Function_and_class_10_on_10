# %% [markdown]
# 400 usually suggests the client sent something invalid or malformed
#
# 401 means authentication is missing or invalid
#
# 403 means the caller is authenticated or known, but not allowed
#
# 500 means the server failed while processing the request
#
# 502/503/504 often point to upstream/proxy/dependency issues

# %% [markdown]
# NGINX initial configuration
#
# ![image.png](attachment:image.png)
