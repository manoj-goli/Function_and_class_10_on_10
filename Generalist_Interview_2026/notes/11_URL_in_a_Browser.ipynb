# %% [markdown]
# Youtube video: https://www.youtube.com/watch?v=AlkDbnbv7dk
#
# Blog: https://bytebytego.com/guides/what-happens-when-you-type-a-url-into-your-browser/

# %% [markdown]
# ![image.png](attachment:image.png)
