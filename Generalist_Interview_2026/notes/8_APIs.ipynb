# %% [markdown]
# APIs:
# Simple Def: Rules that enable communication between software systems
#
# Usual types: Public, Private, Partner
#
#
# ![image.png](attachment:image.png)
#
# ---
# ---

# %% [markdown]
# API Terminologies:
#
# ![image.png](attachment:image.png)
#
# ---
# ---

# %% [markdown]
# REST:
#
# Representational State Transfer, which follows this standard is called RestFul APIs
#
#
# RESTAPIs:
#
# REST is not a specification, but its a loose set of rules
#
# ![image-3.png](attachment:image-3.png)
#
#
# Basics:
# URIs
#
# ![image-5.png](attachment:image-5.png)
#
# Verb Nouns
#
# resources must be nouns
#
# ![image-4.png](attachment:image-4.png)
#
#
# CLIENT interacts with a resource by making a request over HTTP,
# It has a very specific format, see below
#
# ![image-6.png](attachment:image-6.png)
#
#
# Verbs: POST GET PUT DELETE = C R U D
#
#
# CLIENT REQUEST:
# Notice the JSON payload as part of client's request
#
# ![image-7.png](attachment:image-7.png)
#
#
# SERVER RESPONSE:
# Notice the JSON payload return by server after processing the CLIENT's request
#
# ![image-8.png](attachment:image-8.png)
#
#
# ---
# REST implementation should be stateless, good to scale, behaves well
# ---
#
# Paginations:
# If an API endpoint returns a huge amount of data, use pagination
# If not configured the server should assume sensible values as defaults
#
# example pagination scheme:
#
# ![image-9.png](attachment:image-9.png)
#
# ---
#
# Versioning:
# Backward compatibility, moving to next versions cleanly
#
# ![image-10.png](attachment:image-10.png)
# ---
# ---

# %% [markdown]
# Error codes categories:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# ---
#
# Headers and Cookies:
#
# ![image.png](attachment:image.png)
#
#
# ---
# ---

# %% [markdown]
# API Security:
#
# username, token, JWT, Oauth, session based auth (user state), API documentation - swagger, postman, OpenAPISpec - Flask

# %% [markdown]
# ---
# ---
#
# API Features:
#
# ![image.png](attachment:image.png)
#
# pagination:
#
# ![image-2.png](attachment:image-2.png)
#
# URL, Query, Path Parameters
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Idempotency:
#
# ![image.png](attachment:image.png)
#
# Ensures operations can be safely retried

# %% [markdown]
# ---
# ---
#
# API Performance:
#
# ![image.png](attachment:image.png)
#
#
# ### HS + VS <---------
#
# ---
# ---

# %% [markdown]
# API Gateway:
#
# ![image.png](attachment:image.png)
#
# popular tools:
#
# ![image-2.png](attachment:image-2.png)
#
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)
#
# FastAPI: Performance

# %% [markdown]
# This is taking you to System Design stories:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
