# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ingress sucks at managing Multi-Tenancy and it only supports http(s), no support for tcp/udp, rate limiting etc, if wannt do deal with some crazy annotations pile ups
# so I guess no actual production really uses this. So learn GateWay
#
# https://www.udemy.com/course/certified-kubernetes-administrator-with-practice-tests/learn/lecture/48755137#notes
#
# manojmasterofcloud@gmail.com
# N-is-7-0
