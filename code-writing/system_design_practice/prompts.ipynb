# %% [markdown]
# 2) Data-driven value differentiation
#
# This usually means: use numbers to decide, and explain what metric matters.
#
# Framework: “Goal → Metric → Baseline → Change → Tradeoff”
#
# Say things like:
#
# “Success metric is p95 latency / error rate / cost per request…”
#
# “We need a baseline first: last 24h, last deploy, per region…”
#
# “I’d segment: by endpoint, tenant, zone, node pool…”
#
# Example question types
#
# “Which metric tells you this is a CPU vs DB bottleneck?”
#
# “You can only improve one thing this week—what do you pick and why?”
#
# “Show me how you’d prove your fix worked.”
#
# Good lines to memorize
#
# “I’d start with p95 not average.”
#
# “I want correlation with deploys and traffic.”
#
# “I’ll reduce scope: one service, one endpoint, one region.”
#
#
# Overview: Section 2: Data-Driven Value Differentiator
# This part involves evaluating technical scenarios—often related to object storage—and making decisions based on data or specific customer needs
#
# ----
#
# Help me prepare for this with mock questions. Do not overwhelm me with lengthy responses. Lets do this in easy, medium and hard formats. I will let you know when to proceed from easy to medium to hard. Remember this is not a typical 1 hour google software engineer systems design interview. I will only get 15 mins for this section, so this is a mini version of actual SWE Systems Design interview.
#
# In this lets solely focus on my section 2 which is " Data-driven value differentiation"
# In other threads I will practice system design and troubleshooting.

# %% [markdown]
# Section 3: Systems Thinking (System Design)
# Here, you will design high-level systems and explain the flow of data. You may be asked to use a virtual whiteboard or a shared document to visualize components
# ---
# Systems thinking (design)
#
# They’re not expecting a perfect system. They want a sane architecture + tradeoffs + scaling story.
#
# Framework: “Requirements → API → Data → Scale → Failure → Security → Observability”
#
# Requirements (functional + non-functional): QPS, latency, durability, multi-region?
#
# API sketch (inputs/outputs)
#
# Data model (what’s stored? indexes?)
#
# Scale plan (caching, sharding, queues)
#
# Failure modes (retries, idempotency, backpressure)
#
# Security (authn/z, secrets, least privilege)
#
# Observability (SLIs/SLOs, logs/metrics/traces)
#
# ---
#
# Help me prepare for this with mock questions. Do not overwhelm me with lengthy responses. Lets do this in easy, medium and hard formats. I will let you know when to proceed from easy to medium to hard. Remember this is not a typical 1 hour google software engineer systems design interview. I will only get 15 mins for this section, so this is a mini version of actual SWE Systems Design interview.

# %% [markdown]
# section 4:
# Section 4: Troubleshooting
# The goal is to act as a "technical investigator." You should start with scoping questions to understand the expected vs. actual behavior before jumping into a solution
#
# Troubleshooting (Kubernetes-flavored)
#
# They want a methodical triage. Don’t “shotgun” fixes.
#
# Framework: “Scope → Symptoms → Recent changes → Isolate layer → Validate”
#
# Layer-by-layer:
#
# App: logs, config, env vars, feature flags
#
# Pod: readiness/liveness, restarts, OOMKilled, CPU throttling
#
# Node: pressure, disk, kubelet, CNI
#
# Network: DNS, service, ingress, network policies
#
# Dependencies: DB latency, external APIs, rate limits
#
# Commands to mention (not spam, just the right ones)
#
# kubectl get pods -n X
#
# kubectl describe pod ... (events are gold)
#
# kubectl logs ... --previous
#
# kubectl top pod/node (if metrics server exists)
#
# kubectl get events --sort-by=.lastTimestamp
#
# kubectl exec ... -- curl / nslookup (basic network checks)
#
#
# -----
#
#
# Help me get practiced in Linux and Kubernetes. In the Easy, medium, hard way.
# Help me prepare for this with mock questions. Do not overwhelm me with lengthy responses. Lets do this in easy, medium and hard formats. I will let you know when to proceed from easy to medium to hard. Scenario based.
#
# I will ask for clarification questions, do not reveal too much hints while answering my clarification questions. Once I submit my final response, also give rating on a scale of 1 to 10 and a stronger interview answer (this is for me to improve), with areas to focus. Keep feedback brief.

# %% [markdown]
# Details:
#
# Customer & Partner Solutions Engineer (CPSE) role is a hybrid between:
# 	•	Technical Support Engineer (TSE)
# 	•	Solutions Engineer / Customer Engineer
# 	•	Site Reliability / Production Engineer
# 	•	Light Software Engineer (customer-facing tooling)
# 	•	Escalation bridge between customers and product teams
#
# So the interview will test whether you can diagnose real customer problems and implement pragmatic technical solutions — not build complex algorithms from scratch.
#
# ⸻
#
# 🧠 What the role actually needs (based on your description)
#
# They want someone who can:
#
# ✅ Understand production issues quickly
# ✅ Read/modify code (not write large systems)
# ✅ Build small tools/scripts
# ✅ Troubleshoot distributed systems
# ✅ Translate between customers and developers
# ✅ Reduce escalations by solving issues independently
# ✅ Think like an SRE + Solutions Engineer
#
# Not: hardcore LeetCode DP/graph problems.
#
# ⸻
#
# 🧩 What “code writing that evolves into system design” usually means
#
# In these hybrid roles, the interview often follows this arc:
# 	1.	Start with a practical coding task
# 	2.	Add constraints / edge cases
# 	3.	Expand into architecture / scaling / reliability discussion
#
# Think: “Can you build and reason about real systems?”
#
# ⸻
#
# 💻 Likely Coding Tasks (for CPSE)
#
# Expect practical, real-world coding, such as:
#
# 1) Parsing / Processing Data
#
# Much more likely than algorithms.
#
# Examples:
# 	•	Parse logs
# 	•	Process API responses
# 	•	Validate inputs
# 	•	Transform data
# 	•	Handle files
# 	•	Work with timestamps
# 	•	Handle errors gracefully
#
# Example prompt:
#
# “Given server logs, find requests that took longer than X ms.”
#
# ⸻
#
# 2) Debuggable Business Logic
#
# Similar to TSE but you write it.
#
# Examples:
# 	•	Rate limiting logic
# 	•	Billing calculations
# 	•	Order processing
# 	•	Retry logic
# 	•	Deduplication
# 	•	State transitions
#
# ⸻
#
# 3) Small Utility Tool
#
# Very common for support/solutions roles.
#
# Example:
#
# “Write a script that reads a CSV of users and outputs invalid accounts.”
#
# ⸻
#
# 4) API Integration Style Problem
#
# You might simulate:
# 	•	Fetch data
# 	•	Retry on failure
# 	•	Handle pagination
# 	•	Aggregate results
#
# ⸻
#
# 5) Simple Data Structures — Nothing Fancy
#
# Maybe:
# 	•	Dictionaries / hash maps
# 	•	Queues
# 	•	Basic arrays
# 	•	Sets
#
# Almost certainly NOT:
#
# ❌ Dynamic programming
# ❌ Graph algorithms
# ❌ Trees/recursion puzzles
# ❌ Competitive programming tricks
#
# ⸻
#
# 🏗️ How It Evolves into System Design
#
# After your code works, they’ll ask:
#
# “What if this needs to handle millions of requests?”
# “What if multiple customers run this?”
# “How would this work in production?”
# “How would you monitor failures?”
#
# They’re evaluating production thinking.
#
# ⸻
#
# 🔧 Example of a Very Likely CPSE Interview Flow
#
# Step 1 — Coding (20–30 min)
#
# Write a function to process API logs and detect error spikes.
#
# You write something clean and correct.
#
# ⸻
#
# Step 2 — Add Real-World Constraints
#
# They may ask:
# 	•	What about memory limits?
# 	•	What if logs stream continuously?
# 	•	What about malformed input?
# 	•	How would you retry failed API calls?
#
# ⸻
#
# Step 3 — System Design (remaining time)
#
# Now it becomes:
#
# “Design a system to detect anomalies in real time.”
#
# Topics they may probe:
#
# Reliability / Operations
# 	•	Monitoring
# 	•	Alerting
# 	•	Failover
# 	•	Backpressure
# 	•	Rate limits
#
# Scalability
# 	•	Batching
# 	•	Streaming vs batch processing
# 	•	Distributed workers
# 	•	Message queues
#
# Customer-Facing Concerns
# 	•	Multi-tenancy
# 	•	Isolation between partners
# 	•	Security
# 	•	SLAs
#
# ⸻
#
# 🧭 Compared to Google TSE Interview
#
# Google TSE focuses on debugging and troubleshooting.
#
# CPSE likely tests:
#
# 👉 “Can you independently solve customer problems with code + architecture?”
#
# ⸻
#
# 🎯 Topics You SHOULD Prepare
#
# ✅ 1. Clean Practical Coding
#
# In Python/Java/Go (whatever they specified)
#
# Focus on:
# 	•	Dictionaries/maps
# 	•	String processing
# 	•	File handling
# 	•	Error handling
# 	•	Writing readable code
# 	•	Edge cases
#
# Practice problems like:
# 	•	Log parsing
# 	•	CSV processing
# 	•	Request aggregation
# 	•	Rate limiting
# 	•	Basic caching
#
# ⸻
#
# ✅ 2. Production Troubleshooting Mindset
#
# Be ready to talk through:
# 	•	Observability
# 	•	Metrics
# 	•	Logs
# 	•	Tracing
# 	•	Load issues
# 	•	Latency causes
#
# ⸻
#
# ✅ 3. High-Level System Design Basics
#
# Not FAANG L6 architecture.
#
# Focus on:
#
# Core building blocks
# 	•	Load balancer
# 	•	Cache (Redis)
# 	•	Database (SQL vs NoSQL)
# 	•	Message queue (Kafka/SQS)
# 	•	Worker services
# 	•	APIs
#
# ⸻
#
# ✅ 4. Customer-Facing Constraints
#
# Very important for CPSE:
# 	•	Isolation between customers
# 	•	Configuration differences
# 	•	Feature flags
# 	•	Backward compatibility
# 	•	Rollouts
# 	•	Supportability
#
# ⸻
#
# ✅ 5. Debugging & Failure Scenarios
#
# They want someone who prevents escalations.
#
# Expect questions like:
#
# “Customers report slow responses — what do you check first?”
#
# ⸻
#
# 🧪 Example Practice Problem (Very On-Target)
#
# Try this:
#
# Write a function that reads request logs and returns the top N IPs causing errors.
#
# Then think:
# 	•	What if logs are huge?
# 	•	What if logs stream in real time?
# 	•	How to run this across multiple servers?
# 	•	How to alert on spikes?
#
# ⸻
#
# 🧩 What They Are REALLY Testing
#
# Not coding brilliance.
#
# They want evidence that you can:
#
# ✔ Build tools customers need
# ✔ Diagnose production issues
# ✔ Think end-to-end
# ✔ Communicate clearly
# ✔ Work with imperfect requirements
# ✔ Handle ambiguity
#
# ⸻
#
# 🚫 What You Probably DON’T Need
#
# ❌ Advanced algorithms
# ❌ LeetCode hard problems
# ❌ Complex data structures
# ❌ Deep compiler knowledge
# ❌ Formal distributed systems theory
#
# ⸻
#
# 🏆 How to Stand Out (Most Important)
#
# During the interview:
#
# 🔹 Narrate like a production engineer
#
# Say things like:
# 	•	“In a real system I’d monitor this metric…”
# 	•	“We should handle malformed input…”
# 	•	“This could be memory heavy…”
# 	•	“I’d add retries with exponential backoff…”
# 	•	“We should make this idempotent…”
#
# This signals senior troubleshooting capability.
#
# ---
# ___
# You Job:
#
# Role: Act as a Senior Technical mentor at a Tier-1 tech company. Your goal is to help me prepare for this 50-minute technical interview that transitions from a coding task to a system design challenge. (Refer to above details)
#
# User Level: Beginner in Python. Keep the initial problem difficulty at 3/10.
#
# Interview Structure:
#
# Phase 1: Coding (25 mins): Provide a python problem (refer to the details above)
#
# If I ask for clarification, answer like an interviewer: provide context but do not give hints, code snippets, or the answer.
#
# Wait for me to provide the full code and a Big O analysis before moving on.
#
# Phase 2: The Scalability Pivot (25 mins): Once the code is complete, depending on the problem and scenario you may ask me : High level systems design (refer to details),
# Answer my Clarifying Questions
#
# Feedback Requirements:
#
# 1. Provide a rating from 1 to 10 for once the coding section is complete and then again for systems design, repeat the same feedback pattern.
#
# 2. Keep feedback brief and "to the point," focusing on: Code Quality, Communication, and Architectural Logic.
#
# 3. Tips or concepts to improve, keep them to the point and brief
#
# 4. Finally, give me an perfect answer. So I can read and learn from it.
#
# Your First Task:
# Present the first coding problem (Difficulty 3/10) that would eventually make sense to scale up in a productions systems design challenge.
#
# The overall goal is to keep repeating this practice by gradually, I will let you know if the difficulty level needs to be more and you should help me to nail my real interview with this practice.
