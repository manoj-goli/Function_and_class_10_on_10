# %%
def get_recommendations(user_id, graph):
    
    
    return ["item1", "item2", "item3"]  # Example recommendations



get_recommendations("A",{
    "A": ["B", "C"],
    "B": ["C", "D"],
    "C": ["E"],
    "D": ["F"],
    "E": [],
    "F": []
})  

# Expected Output: ["D", "E"]
